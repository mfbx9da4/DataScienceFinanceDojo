# %% [markdown]
# ## This script is the start of trying to determine how identify which issued bonds (rows) are most similar

# %%
import pandas as pd
import numpy as np

# %%
bonds = pd.read_csv('bond_similarity.csv')
print(bonds.shape)
bonds.head()
# Out:
# (1211, 39)
#         Cusip          ISIN         Description  Ticker  Coupon   Maturity  \
# 0  'AL319313'  XS1529687870  AA Bond Co Limited  AABOND   2.875  1/31/2022
# 1  'AO236287'  XS1645315620  AA Bond Co Limited  AABOND   2.750  7/31/2023
# 2  'AT538379'  XS1856940462  AA Bond Co Limited  AABOND   4.875  7/31/2024
# 3  'EJ733791'  XS0949169923  AA Bond Co Limited  AABOND   6.269  7/31/2025
# 4  'EJ944681'  XS0996575378  AA Bond Co Limited  AABOND   4.249  7/31/2020
#
#   Composite Rating Currency Country              Sector Level 1  ...  \
# 0             BBB3      GBP      GB  Securitized/Collateralized  ...
# 1             BBB3      GBP      GB  Securitized/Collateralized  ...
# 2             BBB3      GBP      GB  Securitized/Collateralized  ...
# 3             BBB3      GBP      GB  Securitized/Collateralized  ...
# 4             BBB3      GBP      GB  Securitized/Collateralized  ...
#
#   Prior Month-End Effective Duration Prior Month-End Effective Yield  \
# 0                              3.266                           4.221
# 1                              4.604                           4.204
# 2                              5.168                           4.688
# 3                              5.728                           4.705
# 4                              1.892                           3.549
#
#   Prior Month-End OAS vs Govt TRR % MTD LOC  Excess Rtn % MTD  \
# 0                       331.0         0.184             0.068
# 1                       318.0         0.207             0.071
# 2                       360.0         0.193             0.042
# 3                       354.0         0.273             0.107
# 4                       278.0         0.284             0.202
#
#    Asset Swap Spread  Prior Month-End Asset Swap Spread  OAS vs Swap   \
# 0              235.0                              285.0         243.0
# 1              267.0                              267.0         282.0
# 2              323.0                              323.0         327.0
# 3              433.0                              335.0         418.0
# 4              137.0                              244.0         136.0
#
#    Prior Month-End OAS vs Swap  Illiquidity Premium
# 0                        294.0                  NaN
# 1                        282.0                  NaN
# 2                        327.0                  NaN
# 3                        324.0                  NaN
# 4                        243.0                  NaN
#
# [5 rows x 39 columns]
