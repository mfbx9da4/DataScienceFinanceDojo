# %% [markdown]
# ## This script is the beginning of com

# %%
import pandas as pd
import numpy as np

# %%
tweets = pd.read_excel('201910_Tweets.xlsx')
print(tweets.shape)
tweets.head()
# Out:
# (85607, 29)
#      Query Id                   Date Sentiment Page Type Language  \
# 0  1999962727  2019-10-31 23:58:36.0   neutral   twitter       en
# 1  1999962727  2019-10-31 23:57:46.0   neutral   twitter       en
# 2  1999962727  2019-10-31 23:57:24.0   neutral   twitter       en
# 3  1999962727  2019-10-31 23:54:55.0   neutral   twitter       en
# 4  1999962727  2019-10-31 23:53:34.0  positive   twitter       en
#
#   Country Code      Continent         Country Account Type      City  ...  \
# 0           uk         Europe  United Kingdom   individual  Ramsgate  ...
# 1           in           Asia           India   individual     Surat  ...
# 2           uk         Europe  United Kingdom   individual       NaN  ...
# 3           us  North America   United States   individual       NaN  ...
# 4           us  North America   United States   individual       NaN  ...
#
#      State Thread Entry Type Twitter Followers Twitter Following  \
# ...

# %%
twitter_names=pd.read_csv('FTSE_twitter_accounts.csv')
print(twitter_names.shape)
twitter_names.head()
# Out:
# (182, 3)
#                            name   twitter_handle          isin
# 0            Anglo American PLC    AngloAmerican  GB00B1XZS820
# 1  Associated British Foods PLC   ABFIngredients  GB0006731235
# 2  Associated British Foods PLC  ABFGroceryGrads  GB0006731235
# 3             Admiral Group PLC     AdmiralGroup  GB00B02J6398
# 4             Admiral Group PLC        AdmiralUK  GB00B02J6398

# %%
oct_prices = pd.read_csv('Oct_Price.csv')
print(oct_prices.shape)
oct_prices.head()
# Out:
# (6019, 9)
#         ID_ISIN                NAME        Date             ID  CHG_PCT_1D  \
# 0  GB00B1XZS820  ANGLO AMERICAN PLC  23/08/2019  AAL LN Equity     -0.8330
# 1  GB00B1XZS820  ANGLO AMERICAN PLC  26/08/2019  AAL LN Equity     -0.8330
# 2  GB00B1XZS820  ANGLO AMERICAN PLC  27/08/2019  AAL LN Equity      1.4281
# 3  GB00B1XZS820  ANGLO AMERICAN PLC  28/08/2019  AAL LN Equity      1.6091
# 4  GB00B1XZS820  ANGLO AMERICAN PLC  29/08/2019  AAL LN Equity      1.2343
#
#    PX_HIGH  PX_LOW  PX_OPEN  PX_VOLUME
# 0   1707.4  1654.8   1692.4    4241910
# 1   1707.4  1654.8   1692.4    4241910
# 2   1696.2  1657.0   1660.4    5971130
# 3   1720.2  1673.8   1700.0    3485244
# 4   1753.4  1700.2   1707.8    3751352
