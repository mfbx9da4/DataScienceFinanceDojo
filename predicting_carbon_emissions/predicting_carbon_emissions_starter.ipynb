# %% [markdown]
# ## This is the start of trying to predict carbon emissions from each company (row), base

# %%
import pandas as pd
import numpy as np

# %%
carbon = pd.read_csv('predicting_carbon_emissions.csv')
print(carbon.shape)
carbon.head()
# Out:
# (3987, 65)
#    Account ID                          Company Name Listed    Ticker  \
# 0       30238       Agencia de Proteccion Ambiental    Yes    ADN LN
# 1       59859       Sociedad Comercial del Plata SA    Yes   COME AR
# 2        1408  Banco de Galicia y Buenos Aires S.A.    Yes   GALI AR
# 3       20949                                YPF SA    Yes   YPFD AR
# 4       57626                        Australia Post    Yes  1067Z AU
#
#            ISIN HQ Country  GICS Sector Accounting Year End  \
# 0           NaN        NaN          NaN          29/09/2016
# 1  ARP290071462  Argentina       Energy          31/12/2016
# 2           NaN  Argentina   Financials          31/12/2016
# 3  ARP9897X1319  Argentina       Energy          31/12/2016
# 4             0  Australia  Industrials          30/06/2016
#
#    Reported Scope 1 (tCO2e)   Estimated Scope 1 (tCO2e)   ... Socialindex.1  \
# 0                       0.65                         NaN  ...          0.28
# ...
